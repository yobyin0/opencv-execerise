# %%
import numpy as np 
import cv2 
import os
import matplotlib.pyplot as plt
cv2.__version__

randomByteArrary=bytearray(os.urandom(120000))
flatNumpyArray=np.array(randomByteArrary)
grayImage=flatNumpyArray.reshape(300,400)
#cv2.imwrite('test.png',grayImage)
# %matplotlib inline
plt.axis("off")
plt.imshow(grayImage)
